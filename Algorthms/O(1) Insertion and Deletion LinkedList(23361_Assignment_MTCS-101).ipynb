# %%
class Node:
  def __init__(self,data):
    self.data = data
    self.next = None

# %%
class LinkedList:

  def __init__(self):
    self.head = None
    self.last=None
    self.delet = None

  def insertt(self,data):
    newnode = Node(data)
    dummynode=Node('inf')
    if self.head is None:
      self.head = newnode
      self.last=newnode
      newnode.next = dummynode
      return
    newnode.next=dummynode0
    self.last.next=newnode
    self.last=newnode

  def printList(self):
    present=self.head
    while(present):
      print(present.data)
      present=present.next

  def delete(self,pointer):
      if pointer.data=='inf':
        return "dummy pointer..cant delete"
      if pointer==self.head:
        self.head = self.head.next
      pointer.data=pointer.next.data
      pointer.next=pointer.next.next

  def insertafterpointer(self,pointer,data):
    if pointer.data=="inf":
      return"cant insert after dummy pointer"
    newnode = Node(data)
    newnode.next=pointer.next
    pointer.next=newnode

# %%
class LinkedList:

  def __init__(self):
    self.head = None
    self.last=None
    self.delet = None

  def insertt(self,data,dummynode):
    newnode = Node(data)
    if self.head is None:
      self.head = newnode
      self.last=newnode
      newnode.next = dummynode
      return
    newnode.next=dummynode
    self.last.next=newnode
    self.last=newnode

  def printList(self):
    present=self.head
    while(present):
      print(present.data)
      present=present.next

  def delete(self,pointer):
      if pointer.data=='inf':
        return "dummy pointer..cant delete"
      if pointer==self.head:
        self.head = self.head.next
      pointer.data=pointer.next.data
      pointer.next=pointer.next.next

  def insertafterpointer(self,pointer,data):
    if pointer.data=="inf":
      return"cant insert after dummy pointer"
    newnode = Node(data)
    newnode.next=pointer.next
    pointer.next=newnode

# %%
linklist = LinkedList()
dummynode=Node('inf')

linklist.insertt('a',dummynode)
linklist.insertt('b',dummynode)
linklist.insertt('c',dummynode)
linklist.insertt('d',dummynode)
linklist.insertt('a',dummynode)
linklist.insertt('b',dummynode)
linklist.insertt('c',dummynode)
linklist.insertt('d',dummynode)

# %%
linklist.printList()
# Out:
# a
# b
# c
# d
# a
# b
# c
# d
# inf

# %%
linklist.delete(linklist.head)

# %%
linklist.head.data
# Out:
# 'b'

# %%
linklist.insertafterpointer(linklist.head,'hh')

# %%
linklist.printList()
# Out:
# b
# hh
# c
# d
# a
# b
# c
# d
# inf

# %%
linklist.delete(linklist.head.next.next.next)

# %%
linklist.printList()
# Out:
# b
# hh
# c
# a
# b
# c
# d
# inf

# %%
linklist.delete(linklist.head.next.next.next.next.next.next) #deleting the last node on O(1) time

# %%
linklist.printList()
# Out:
# b
# hh
# c
# a
# b
# c
# inf
